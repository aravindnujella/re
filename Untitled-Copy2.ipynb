# %%
import model_lib
import numpy as np
import warnings
warnings.filterwarnings('ignore', '.*output shape of zoom.*')
import pickle
import importlib
importlib.reload(model_lib)
import os
import time
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

# %%
# config to train
# TODO: check Config is correct
class ProposalConfig():
    NAME = "InSegm"
    GPU_COUNT = 1
    # online training
    IMAGES_PER_GPU = 36
    STEPS_PER_EPOCH = 100
    NUM_WORKERS = 16
    PIN_MEMORY = True
    DATA_ORDER = "cw_ins"
    VALIDATION_STEPS = 20
    # including gt
    NUM_CLASSES = 81
    
    # only flips
    MEAN_PIXEL = np.array([0.485, 0.456, 0.406],dtype=np.float32).reshape(1,1,-1)
    STD_PIXEL = np.array([0.229, 0.224, 0.225],dtype=np.float32).reshape(1,1,-1)
    CLASS_NAMES = [
        'BG', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
        'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign',
        'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep',
        'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella',
        'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard',
        'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard',
        'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork',
        'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange',
        'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair',
        'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv',
        'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave',
        'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase',
        'scissors', 'teddy bear', 'hair drier', 'toothbrush'
    ]
    WIDTH = 224
    HEIGHT = 224
    CROP_SIZE = 224
    def __init__(self):
        self.BATCH_SIZE = self.IMAGES_PER_GPU * self.GPU_COUNT
        self.IMAGE_SHAPE = (self.WIDTH, self.HEIGHT,3)

    def display(self):
        """Display Configuration values."""
        print("\nConfigurations:")
        for a in dir(self):
            if not a.startswith("__") and not callable(getattr(self, a)):
                print("{:30} {}".format(a, getattr(self, a)))
        print("\n")

# %%
train_image_dir = "/media/data/nishanth/aravind/train2017/"
# train_image_dir = "/media/data/nishanth/aravind/val2017/"
val_image_dir = "/media/data/nishanth/aravind/val2017/"
config = ProposalConfig()
model_dir = "./models/"
train_pickle = "/home/aravind/re/data/train_cwid.pickle"
# train_pickle = "/home/aravind/re/data/val_cwid.pickle"
val_pickle = "/home/aravind/re/data/val_cwid.pickle"

# %%
with open(train_pickle,"rb") as train_ann:
    train_cwid = pickle.load(train_ann)
with open(val_pickle,"rb") as val_ann:
    val_cwid = pickle.load(val_ann)

# %%
train_loader = model_lib.get_loader(train_cwid,config,train_image_dir)
val_loader = model_lib.get_loader(val_cwid,config,val_image_dir)
# for j in enumerate(train_loader):
#     k = j

# %%
import torch.optim as optim
import torch
import torch.nn.functional as F
net = model_lib.SimpleHGModel()

# %%
# net.vgg0.load_state_dict(torch.load("./models/split_vgg16_features_10.pt"))
# pretrained_dict = torch.load(model_dir+"model_mask_vgg_2.pt")
pretrained_dict = torch.load(model_dir+"split_vgg_3.pt")

net_dict = net.state_dict()
pretrained_dict = {k: v for k, v in pretrained_dict.items() if k in net_dict}
net_dict.update(pretrained_dict) 
net.load_state_dict(net_dict)

# %%
net_size = sum([i.numel() for i in net.parameters()])
def set_trainable(module,state):
    for param in module.parameters():
        param.requires_grad = state

set_trainable(net,False)
set_trainable(net.mp0,True)
set_trainable(net.class_predictor,True)
for name,child in net.vgg0.named_children():
    if name[:-1] == "layer":
        [set_trainable(s.copy_filters,True) for s in child[::3]]
        [set_trainable(s.ignore_filters,False) for s in child[::3]]
        [set_trainable(s,True) for s in child[1::3]]
    elif name[:-1] == "wing_conv":
        set_trainable(child,True)
trainable_params = filter(lambda p: p.requires_grad, net.parameters())
trainable_size = sum([i.numel() for i in trainable_params])
print(net_size,trainable_size)
net = net.cuda()
# Out:
# 31363332 12965700

# %%
# net.load_state_dict(torch.load(model_dir+"model_bce_0_2600.pt"))
optimizer = optim.SGD(filter(lambda p: p.requires_grad, net.parameters()), lr=0.001, momentum=0.9)
# optimizer = optim.Adam(filter(lambda p: p.requires_grad, net.parameters()),lr = 0.001)

iters_per_checkpoint = 60
for epoch in range(10000):  # loop over the dataset multiple times
    running_loss = 0.0
    for i,data in enumerate(train_loader,0):
        batch_images,batch_impulses,batch_gt_responses,batch_one_hot = data
        batch_images,batch_impulses,batch_gt_responses,batch_one_hot = batch_images.cuda(),batch_impulses.cuda(),batch_gt_responses.cuda(),batch_one_hot.cuda()
        # zero the parameter gradients
        optimizer.zero_grad()
        # forward + backward + optimize
        pred_class,pred_masks = net([batch_images,batch_impulses])
        # we are giving no weighting for classes...
        class_loss,mask_loss = model_lib.loss_criterion(pred_class,batch_one_hot,pred_masks,batch_gt_responses)
#         loss = class_loss+mask_loss
        loss = mask_loss
        # print(class_loss.item(),mask_loss.item())
        loss.backward()
        optimizer.step()
        running_loss += loss.item() 
        if i % iters_per_checkpoint == 0:
            print("batch: ",i,"epoch: ",epoch, "loss: %0.5f" % (running_loss/iters_per_checkpoint))
#             torch.save(net.state_dict(),model_dir+("model_mask_vgg_%d_%d.pt")%(2,2))
            torch.save(net.state_dict(),model_dir+("split_vgg_full.pt"))
            running_loss = 0.0
    # print("batch: %d time:%0.3f sec" %(i, end-start)); print(loss.item())
print('Finished Training')
# Out:
# batch:  0 epoch:  0 loss: 0.00109
# batch:  60 epoch:  0 loss: 0.06549
# batch:  120 epoch:  0 loss: 0.06630
# batch:  180 epoch:  0 loss: 0.06507
# batch:  240 epoch:  0 loss: 0.06562
# batch:  300 epoch:  0 loss: 0.06606
# batch:  360 epoch:  0 loss: 0.06570
# batch:  420 epoch:  0 loss: 0.06566
# batch:  480 epoch:  0 loss: 0.06553
# batch:  540 epoch:  0 loss: 0.06568
# batch:  600 epoch:  0 loss: 0.06559
# batch:  660 epoch:  0 loss: 0.06599
# batch:  720 epoch:  0 loss: 0.06613
# batch:  780 epoch:  0 loss: 0.06519
# batch:  840 epoch:  0 loss: 0.06534
# batch:  900 epoch:  0 loss: 0.06551
# batch:  960 epoch:  0 loss: 0.06532
# batch:  1020 epoch:  0 loss: 0.06535
# batch:  1080 epoch:  0 loss: 0.06566
# batch:  1140 epoch:  0 loss: 0.06531
# batch:  1200 epoch:  0 loss: 0.06557
# batch:  1260 epoch:  0 loss: 0.06574
# batch:  1320 epoch:  0 loss: 0.06623
# batch:  1380 epoch:  0 loss: 0.06564
# batch:  1440 epoch:  0 loss: 0.06534
# batch:  1500 epoch:  0 loss: 0.06618
# batch:  1560 epoch:  0 loss: 0.06563
# batch:  1620 epoch:  0 loss: 0.06554
# batch:  1680 epoch:  0 loss: 0.06566
# batch:  1740 epoch:  0 loss: 0.06528
# batch:  1800 epoch:  0 loss: 0.06549
# batch:  1860 epoch:  0 loss: 0.06538
# batch:  1920 epoch:  0 loss: 0.06584
# batch:  1980 epoch:  0 loss: 0.06596
# batch:  2040 epoch:  0 loss: 0.06515
# batch:  2100 epoch:  0 loss: 0.06584
# batch:  2160 epoch:  0 loss: 0.06584
# batch:  2220 epoch:  0 loss: 0.06571
# batch:  2280 epoch:  0 loss: 0.06606
# batch:  2340 epoch:  0 loss: 0.06570
# batch:  2400 epoch:  0 loss: 0.06554
# batch:  2460 epoch:  0 loss: 0.06558
# batch:  2520 epoch:  0 loss: 0.06568
# batch:  2580 epoch:  0 loss: 0.06474
# batch:  2640 epoch:  0 loss: 0.06533
# batch:  2700 epoch:  0 loss: 0.06521
# batch:  2760 epoch:  0 loss: 0.06565
# batch:  2820 epoch:  0 loss: 0.06625
# batch:  2880 epoch:  0 loss: 0.06546
# batch:  2940 epoch:  0 loss: 0.06448
# batch:  3000 epoch:  0 loss: 0.06519
# batch:  3060 epoch:  0 loss: 0.06485
# batch:  3120 epoch:  0 loss: 0.06538
# batch:  3180 epoch:  0 loss: 0.06525
# batch:  3240 epoch:  0 loss: 0.06508
# batch:  3300 epoch:  0 loss: 0.06518
# batch:  3360 epoch:  0 loss: 0.06504
# batch:  3420 epoch:  0 loss: 0.06527
# batch:  3480 epoch:  0 loss: 0.06476
# batch:  3540 epoch:  0 loss: 0.06428
# batch:  3600 epoch:  0 loss: 0.06496
# batch:  3660 epoch:  0 loss: 0.06532
# batch:  3720 epoch:  0 loss: 0.06485
# batch:  3780 epoch:  0 loss: 0.06553
# batch:  3840 epoch:  0 loss: 0.06548
# batch:  3900 epoch:  0 loss: 0.06540
# batch:  3960 epoch:  0 loss: 0.06466
# batch:  4020 epoch:  0 loss: 0.06458
# batch:  4080 epoch:  0 loss: 0.06486
# batch:  4140 epoch:  0 loss: 0.06462
# batch:  4200 epoch:  0 loss: 0.06535
# batch:  4260 epoch:  0 loss: 0.06531
# batch:  4320 epoch:  0 loss: 0.06541
# batch:  4380 epoch:  0 loss: 0.06476
# batch:  4440 epoch:  0 loss: 0.06511
# batch:  4500 epoch:  0 loss: 0.06563
# batch:  4560 epoch:  0 loss: 0.06483
# batch:  4620 epoch:  0 loss: 0.06520
# batch:  4680 epoch:  0 loss: 0.06507
# batch:  4740 epoch:  0 loss: 0.06543
# batch:  4800 epoch:  0 loss: 0.06574
# batch:  4860 epoch:  0 loss: 0.06524
# batch:  4920 epoch:  0 loss: 0.06521
# batch:  4980 epoch:  0 loss: 0.06488
# batch:  5040 epoch:  0 loss: 0.06409
# batch:  5100 epoch:  0 loss: 0.06486
# batch:  5160 epoch:  0 loss: 0.06560
# batch:  5220 epoch:  0 loss: 0.06566
# batch:  5280 epoch:  0 loss: 0.06504
# batch:  5340 epoch:  0 loss: 0.06475
# batch:  5400 epoch:  0 loss: 0.06428
# batch:  5460 epoch:  0 loss: 0.06490
# batch:  5520 epoch:  0 loss: 0.06474
# batch:  5580 epoch:  0 loss: 0.06559
# batch:  5640 epoch:  0 loss: 0.06567
# batch:  5700 epoch:  0 loss: 0.06485
# batch:  5760 epoch:  0 loss: 0.06541
# batch:  5820 epoch:  0 loss: 0.06542
# batch:  5880 epoch:  0 loss: 0.06544
# batch:  5940 epoch:  0 loss: 0.06571
# batch:  6000 epoch:  0 loss: 0.06520
# batch:  6060 epoch:  0 loss: 0.06465
# batch:  6120 epoch:  0 loss: 0.06534
# batch:  6180 epoch:  0 loss: 0.06542
# batch:  6240 epoch:  0 loss: 0.06502
# batch:  6300 epoch:  0 loss: 0.06489
# batch:  6360 epoch:  0 loss: 0.06448
# batch:  6420 epoch:  0 loss: 0.06538
# batch:  6480 epoch:  0 loss: 0.06465
# batch:  6540 epoch:  0 loss: 0.06487
# batch:  6600 epoch:  0 loss: 0.06449
# batch:  6660 epoch:  0 loss: 0.06505
# batch:  6720 epoch:  0 loss: 0.06478
# batch:  6780 epoch:  0 loss: 0.06533
# batch:  6840 epoch:  0 loss: 0.06518
# batch:  6900 epoch:  0 loss: 0.06467
# batch:  6960 epoch:  0 loss: 0.06443
# batch:  7020 epoch:  0 loss: 0.06525
# batch:  7080 epoch:  0 loss: 0.06507
# batch:  7140 epoch:  0 loss: 0.06485
# batch:  7200 epoch:  0 loss: 0.06499
# batch:  7260 epoch:  0 loss: 0.06481
# batch:  7320 epoch:  0 loss: 0.06449
# batch:  7380 epoch:  0 loss: 0.06550
# batch:  7440 epoch:  0 loss: 0.06539
# batch:  7500 epoch:  0 loss: 0.06487
# batch:  7560 epoch:  0 loss: 0.06433
# batch:  7620 epoch:  0 loss: 0.06558
# batch:  7680 epoch:  0 loss: 0.06464
# batch:  7740 epoch:  0 loss: 0.06538
# batch:  7800 epoch:  0 loss: 0.06491
# batch:  7860 epoch:  0 loss: 0.06425
# batch:  7920 epoch:  0 loss: 0.06520
# batch:  7980 epoch:  0 loss: 0.06452
# batch:  8040 epoch:  0 loss: 0.06476
# batch:  8100 epoch:  0 loss: 0.06508
# batch:  8160 epoch:  0 loss: 0.06482
# batch:  8220 epoch:  0 loss: 0.06528
# batch:  8280 epoch:  0 loss: 0.06444
# batch:  8340 epoch:  0 loss: 0.06517
# batch:  8400 epoch:  0 loss: 0.06485
# batch:  8460 epoch:  0 loss: 0.06403
# batch:  8520 epoch:  0 loss: 0.06500
# batch:  8580 epoch:  0 loss: 0.06485
# batch:  8640 epoch:  0 loss: 0.06445
# batch:  8700 epoch:  0 loss: 0.06480
# batch:  8760 epoch:  0 loss: 0.06435
# batch:  8820 epoch:  0 loss: 0.06432
# batch:  8880 epoch:  0 loss: 0.06441
# batch:  8940 epoch:  0 loss: 0.06428
# batch:  9000 epoch:  0 loss: 0.06559
# batch:  9060 epoch:  0 loss: 0.06463
# batch:  9120 epoch:  0 loss: 0.06431
# batch:  9180 epoch:  0 loss: 0.06425
# batch:  9240 epoch:  0 loss: 0.06478
# batch:  9300 epoch:  0 loss: 0.06417
# batch:  9360 epoch:  0 loss: 0.06480
# batch:  9420 epoch:  0 loss: 0.06373
# batch:  9480 epoch:  0 loss: 0.06424
# batch:  9540 epoch:  0 loss: 0.06443
# batch:  9600 epoch:  0 loss: 0.06476
# batch:  9660 epoch:  0 loss: 0.06460
# batch:  9720 epoch:  0 loss: 0.06474
# batch:  9780 epoch:  0 loss: 0.06448
# batch:  9840 epoch:  0 loss: 0.06430
# batch:  9900 epoch:  0 loss: 0.06495
# batch:  9960 epoch:  0 loss: 0.06435
# batch:  10020 epoch:  0 loss: 0.06438
# batch:  10080 epoch:  0 loss: 0.06454
# batch:  10140 epoch:  0 loss: 0.06452
# batch:  10200 epoch:  0 loss: 0.06448
# batch:  10260 epoch:  0 loss: 0.06538
# batch:  10320 epoch:  0 loss: 0.06480
# batch:  10380 epoch:  0 loss: 0.06498
# batch:  10440 epoch:  0 loss: 0.06415
# batch:  10500 epoch:  0 loss: 0.06403
# batch:  10560 epoch:  0 loss: 0.06483
# batch:  10620 epoch:  0 loss: 0.06451
# batch:  10680 epoch:  0 loss: 0.06488
# batch:  10740 epoch:  0 loss: 0.06367
# batch:  10800 epoch:  0 loss: 0.06474
# batch:  10860 epoch:  0 loss: 0.06467
# batch:  10920 epoch:  0 loss: 0.06462
# batch:  10980 epoch:  0 loss: 0.06429
# batch:  11040 epoch:  0 loss: 0.06496
# batch:  11100 epoch:  0 loss: 0.06440
# batch:  11160 epoch:  0 loss: 0.06453
# batch:  11220 epoch:  0 loss: 0.06349
# batch:  11280 epoch:  0 loss: 0.06431
# batch:  11340 epoch:  0 loss: 0.06448
# batch:  11400 epoch:  0 loss: 0.06442
# batch:  11460 epoch:  0 loss: 0.06396
# batch:  11520 epoch:  0 loss: 0.06403
# batch:  11580 epoch:  0 loss: 0.06427
# batch:  11640 epoch:  0 loss: 0.06462
# batch:  11700 epoch:  0 loss: 0.06480
# batch:  11760 epoch:  0 loss: 0.06379
# batch:  11820 epoch:  0 loss: 0.06448
# batch:  11880 epoch:  0 loss: 0.06452
# batch:  11940 epoch:  0 loss: 0.06442
# batch:  12000 epoch:  0 loss: 0.06420
# batch:  12060 epoch:  0 loss: 0.06441
# batch:  12120 epoch:  0 loss: 0.06461
# batch:  12180 epoch:  0 loss: 0.06359
# batch:  12240 epoch:  0 loss: 0.06342
# batch:  12300 epoch:  0 loss: 0.06486
# batch:  12360 epoch:  0 loss: 0.06391
# batch:  12420 epoch:  0 loss: 0.06419
# batch:  12480 epoch:  0 loss: 0.06451
# batch:  12540 epoch:  0 loss: 0.06420
# batch:  12600 epoch:  0 loss: 0.06397
# batch:  12660 epoch:  0 loss: 0.06412
# batch:  12720 epoch:  0 loss: 0.06472
# batch:  12780 epoch:  0 loss: 0.06417
# batch:  12840 epoch:  0 loss: 0.06455
# batch:  12900 epoch:  0 loss: 0.06472
# batch:  12960 epoch:  0 loss: 0.06472
# batch:  13020 epoch:  0 loss: 0.06453
# batch:  13080 epoch:  0 loss: 0.06419
# batch:  13140 epoch:  0 loss: 0.06456
# batch:  13200 epoch:  0 loss: 0.06476
# batch:  13260 epoch:  0 loss: 0.06460
# batch:  13320 epoch:  0 loss: 0.06428
# batch:  13380 epoch:  0 loss: 0.06464
# batch:  13440 epoch:  0 loss: 0.06431
# batch:  13500 epoch:  0 loss: 0.06395
# batch:  13560 epoch:  0 loss: 0.06399
# batch:  13620 epoch:  0 loss: 0.06347
# batch:  13680 epoch:  0 loss: 0.06421
# batch:  13740 epoch:  0 loss: 0.06503
# batch:  13800 epoch:  0 loss: 0.06394
# batch:  13860 epoch:  0 loss: 0.06392
# batch:  13920 epoch:  0 loss: 0.06475
# batch:  13980 epoch:  0 loss: 0.06454
# batch:  14040 epoch:  0 loss: 0.06395
# batch:  14100 epoch:  0 loss: 0.06414
# batch:  14160 epoch:  0 loss: 0.06402
# batch:  14220 epoch:  0 loss: 0.06452
# batch:  14280 epoch:  0 loss: 0.06410
# batch:  14340 epoch:  0 loss: 0.06380
# batch:  14400 epoch:  0 loss: 0.06431
# batch:  14460 epoch:  0 loss: 0.06360
# batch:  14520 epoch:  0 loss: 0.06412
# batch:  14580 epoch:  0 loss: 0.06419
# batch:  14640 epoch:  0 loss: 0.06456
# batch:  14700 epoch:  0 loss: 0.06421
# batch:  14760 epoch:  0 loss: 0.06360
# batch:  14820 epoch:  0 loss: 0.06399
# batch:  14880 epoch:  0 loss: 0.06443
# batch:  14940 epoch:  0 loss: 0.06347
# batch:  15000 epoch:  0 loss: 0.06437
# batch:  15060 epoch:  0 loss: 0.06371
# batch:  15120 epoch:  0 loss: 0.06472
# batch:  15180 epoch:  0 loss: 0.06399
# batch:  15240 epoch:  0 loss: 0.06386
# batch:  15300 epoch:  0 loss: 0.06440
# batch:  15360 epoch:  0 loss: 0.06424
# batch:  15420 epoch:  0 loss: 0.06444
# batch:  15480 epoch:  0 loss: 0.06336
# batch:  15540 epoch:  0 loss: 0.06439
# batch:  15600 epoch:  0 loss: 0.06388
# batch:  15660 epoch:  0 loss: 0.06483
# batch:  15720 epoch:  0 loss: 0.06443
# batch:  15780 epoch:  0 loss: 0.06421
# batch:  15840 epoch:  0 loss: 0.06381
# batch:  15900 epoch:  0 loss: 0.06400
# batch:  15960 epoch:  0 loss: 0.06423
# batch:  16020 epoch:  0 loss: 0.06446
# batch:  16080 epoch:  0 loss: 0.06367
# batch:  16140 epoch:  0 loss: 0.06347
# batch:  16200 epoch:  0 loss: 0.06309
# batch:  16260 epoch:  0 loss: 0.06442
# batch:  16320 epoch:  0 loss: 0.06420
# batch:  16380 epoch:  0 loss: 0.06399
# batch:  16440 epoch:  0 loss: 0.06368
# batch:  16500 epoch:  0 loss: 0.06386
# batch:  16560 epoch:  0 loss: 0.06372
# batch:  16620 epoch:  0 loss: 0.06444
# batch:  16680 epoch:  0 loss: 0.06432
# batch:  16740 epoch:  0 loss: 0.06411
# batch:  16800 epoch:  0 loss: 0.06431
# batch:  16860 epoch:  0 loss: 0.06447
# batch:  16920 epoch:  0 loss: 0.06377
# batch:  16980 epoch:  0 loss: 0.06343
# batch:  17040 epoch:  0 loss: 0.06379
# batch:  17100 epoch:  0 loss: 0.06298
# batch:  17160 epoch:  0 loss: 0.06349
# batch:  17220 epoch:  0 loss: 0.06401
# batch:  17280 epoch:  0 loss: 0.06438
# batch:  17340 epoch:  0 loss: 0.06354
# batch:  17400 epoch:  0 loss: 0.06378
# batch:  17460 epoch:  0 loss: 0.06384
# batch:  17520 epoch:  0 loss: 0.06433
# batch:  17580 epoch:  0 loss: 0.06397
# batch:  17640 epoch:  0 loss: 0.06371
# batch:  17700 epoch:  0 loss: 0.06402
# batch:  17760 epoch:  0 loss: 0.06346
# batch:  17820 epoch:  0 loss: 0.06422
# batch:  17880 epoch:  0 loss: 0.06392
# batch:  17940 epoch:  0 loss: 0.06409
# batch:  18000 epoch:  0 loss: 0.06369
# batch:  18060 epoch:  0 loss: 0.06468
# batch:  18120 epoch:  0 loss: 0.06318
# batch:  18180 epoch:  0 loss: 0.06426
# batch:  18240 epoch:  0 loss: 0.06476
# batch:  18300 epoch:  0 loss: 0.06387
# batch:  18360 epoch:  0 loss: 0.06398
# batch:  18420 epoch:  0 loss: 0.06415
# batch:  18480 epoch:  0 loss: 0.06381
# batch:  18540 epoch:  0 loss: 0.06425
# batch:  18600 epoch:  0 loss: 0.06330
# batch:  18660 epoch:  0 loss: 0.06378
# batch:  18720 epoch:  0 loss: 0.06349
# batch:  18780 epoch:  0 loss: 0.06400
# batch:  18840 epoch:  0 loss: 0.06329
# batch:  18900 epoch:  0 loss: 0.06424
# batch:  18960 epoch:  0 loss: 0.06329
# batch:  19020 epoch:  0 loss: 0.06346
# batch:  19080 epoch:  0 loss: 0.06381
# batch:  19140 epoch:  0 loss: 0.06371
# batch:  19200 epoch:  0 loss: 0.06391
# batch:  19260 epoch:  0 loss: 0.06393
# batch:  19320 epoch:  0 loss: 0.06336
# batch:  19380 epoch:  0 loss: 0.06391
# batch:  19440 epoch:  0 loss: 0.06369
# batch:  19500 epoch:  0 loss: 0.06357
# batch:  19560 epoch:  0 loss: 0.06339
# batch:  19620 epoch:  0 loss: 0.06479
# batch:  19680 epoch:  0 loss: 0.06445
# batch:  19740 epoch:  0 loss: 0.06385
# batch:  19800 epoch:  0 loss: 0.06414
# batch:  19860 epoch:  0 loss: 0.06398
# batch:  19920 epoch:  0 loss: 0.06356
# batch:  19980 epoch:  0 loss: 0.06399
# batch:  20040 epoch:  0 loss: 0.06394
# batch:  20100 epoch:  0 loss: 0.06410
# batch:  20160 epoch:  0 loss: 0.06429
